# %% [markdown]
# ## 1번 문제

# %%
def 스택풀확인():
    global SIZE, stack, top
    if (top >= SIZE-1):
        return True
    else:
        return False
    
def 스택엠티확인():
    global SIZE, stack, top
    if (top == -1):
        return True
    else:
        return False
    
def 스택푸쉬(data):
    global SIZE, stack, top
    if(스택풀확인()):
        print('스택이 꽉 찼습니다.')
        return
    top += 1
    stack[top] = data

def 스택팝():
    global SIZE, stack, top
    if (스택엠티확인()):
        print('스택이 비었습니다.')
        return None
    data = stack[top]
    stack[top] = None
    top -= 1
    return data

def 스택피크():
    global SIZE, stack, top
    if (스택엠티확인()):
        print("스택이 비었습니다.")
        return None
    return stack[top]

SIZE = int(input('스택 크기를 입력하세요 ==> '))
stack = [None for _ in range(SIZE)]
top = -1

if __name__ == '__main__':
    select = input('삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> ')

    while (select != 'X' and select != 'x'):
        if select == 'I' or select == 'i':
            data = input('입력할 데이터 ==> ')
            스택푸쉬(data)
            print('스택 상태 : ', stack)
        elif select == 'E' or select == 'e':
            data = 스택팝()
            print('추출된 데이터 ==> ', data)
            print('스택 상태 : ', stack)
        elif select == 'V' or select == 'v':
            data = 스택피크()
            print('확인된 데이터 ==> ', data)
            print('스택 상태 : ', stack)
        else:
            print('입력이 잘못됨')

        select = input('삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> ')

    print('프로그램 종료!')
# Out:
# 스택 상태 :  ['리신', None, None, None, None]
# 스택 상태 :  ['리신', '그레이브즈', None, None, None]
# 스택 상태 :  ['리신', '그레이브즈', '바이', None, None]
# 스택 상태 :  ['리신', '그레이브즈', '바이', '니달리', None]
# 스택 상태 :  ['리신', '그레이브즈', '바이', '니달리', '브랜드']
# 확인된 데이터 ==>  브랜드
# 스택 상태 :  ['리신', '그레이브즈', '바이', '니달리', '브랜드']
# 확인된 데이터 ==>  브랜드
# 스택 상태 :  ['리신', '그레이브즈', '바이', '니달리', '브랜드']
# 확인된 데이터 ==>  브랜드
# 스택 상태 :  ['리신', '그레이브즈', '바이', '니달리', '브랜드']
# 추출된 데이터 ==>  브랜드
# 스택 상태 :  ['리신', '그레이브즈', '바이', '니달리', None]
# 추출된 데이터 ==>  니달리
# 스택 상태 :  ['리신', '그레이브즈', '바이', None, None]
# 추출된 데이터 ==>  바이
# 스택 상태 :  ['리신', '그레이브즈', None, None, None]
# 추출된 데이터 ==>  그레이브즈
# 스택 상태 :  ['리신', None, None, None, None]
# 추출된 데이터 ==>  리신
# 스택 상태 :  [None, None, None, None, None]
# 스택이 비었습니다.
# 추출된 데이터 ==>  None
# 스택 상태 :  [None, None, None, None, None]
# 프로그램 종료!

# %% [markdown]
# ## 2번 문제

# %%
def isQueueFull():
    global SIZE, queue, front, rear
    if (rear == SIZE-1):
        return True
    else:
        return False
    
def isQueueEmpty():
    global SIZE, queue, front, rear
    if (front == rear):
        return True
    else:
        return False
    
def enQueue(data):
    global SIZE, queue, front, rear
    if (isQueueFull()):
        print('큐가 꽉찼습니다')
        return
    rear += 1
    queue[rear] = data

def deQueue():
    global SIZE, queue, front, rear
    if (isQueueEmpty()):
        print('큐가 비었습니다.')
        return None
    front += 1
    data = queue[front]
    queue[front] = None

    for i in range(front+1, rear+1):
        queue[i-1] = queue[i]
        queue[i] = None
    front = -1
    rear -= 1

    return data

def 스택피크():
    global SIZE, queue, front, rear
    if(isQueueEmpty()):
        print('큐가 비었습니다.')
        return None
    return queue[front+1]

SIZE = 5
queue = [None for _ in range(SIZE)]
front = rear = -1

if __name__ == '__main__': # 메인 시작
    while True:
        select = input('삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> ')

        if select.lower() == 'e':
            data = input('입력 데이터 >')
            enQueue(data)
            print(f'큐상태 : {queue}')
        elif select.lower() == 'd':
            data = deQueue()
            print(f'추출데이터 > {data}')
            print(f'큐상태 : {queue}')
        elif select.lower() == 'p':
            data = 스택피크()
            print(f'확인데이터 > {data}')
            print(f'큐상태 : {queue}')
        elif select.lower() == 'x':
            break
        else:
            continue
# Out:
# 큐상태 : ['정국', None, None, None, None]
# 큐상태 : ['정국', '뷔', None, None, None]
# 큐상태 : ['정국', '뷔', '지민', None, None]
# 큐상태 : ['정국', '뷔', '지민', '진', None]
# 큐상태 : ['정국', '뷔', '지민', '진', '슈가']
# 추출데이터 > 정국
# 큐상태 : ['뷔', '지민', '진', '슈가', None]
# 추출데이터 > 뷔
# 큐상태 : ['지민', '진', '슈가', None, None]
# 추출데이터 > 지민
# 큐상태 : ['진', '슈가', None, None, None]
# 추출데이터 > 진
# 큐상태 : ['슈가', None, None, None, None]
# 추출데이터 > 슈가
# 큐상태 : [None, None, None, None, None]
# 큐가 비었습니다.
# 추출데이터 > None
# 큐상태 : [None, None, None, None, None]

# %% [markdown]
# ## 3번 문제

# %%
import random

class TreeNode():
    def __init__(self):
        self.left = None
        self.data = None
        self.right = None

def preorder(node):
    if node == None:
        return
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

memory = []
root = None
dataAry = []

if __name__ == '__main__':
    while True:
        select = input('편의점 물품 삽입(I)/오늘 판매된 물건(중복O)확인(E)/오늘 판매된 종류(중복X)확인(V)/종료(X) 중 하나를 선택 ==> ')

        if select == 'I' or select == 'i':
            s = input('물품을 입력하세요 -> ')
            dataAry.append(s)
            print(dataAry)
        elif select == 'E' or select == 'e':
            sellAry = [random.choice(dataAry) for _ in range(20)]
            print('오늘 판매된 물건(중복O) -->', sellAry)
        elif select == 'V' or select == 'v':
            node = TreeNode()
            node.data = sellAry[0]
            root = node
            memory.append(node)

            for name in sellAry[1:]:

                node = TreeNode()
                node.data = name
                    
                current = root
                while True:
                    if name == current.data: break
                    if name < current.data:
                        if current.left == None:
                            current.left = node
                            memory.append(node)
                            break
                        current = current.left
                    else:
                        if current.right == None:
                            current.right = node
                            memory.append(node)
                            break
                        current = current.right
            print('이진 탐색 트리 구성 완료!')
            print('오늘 판매된 종류(중복X)--> ', end=' ')
            preorder(root)
        elif select == 'X' or select == 'x':
            break
        else:
            continue
# Out:
# ['바나나맛우유']
# ['바나나맛우유', '레쓰비캔커피']
# ['바나나맛우유', '레쓰비캔커피', '츄파춥스']
# ['바나나맛우유', '레쓰비캔커피', '츄파춥스', '도시락']
# ['바나나맛우유', '레쓰비캔커피', '츄파춥스', '도시락', '삼다수']
# ['바나나맛우유', '레쓰비캔커피', '츄파춥스', '도시락', '삼다수', '코카콜라']
# ['바나나맛우유', '레쓰비캔커피', '츄파춥스', '도시락', '삼다수', '코카콜라', '삼각김밥']
# 오늘 판매된 물건(중복O) --> ['삼각김밥', '삼다수', '츄파춥스', '레쓰비캔커피', '삼각김밥', '삼다수', '삼다수', '삼다수', '레쓰비캔커피', '츄파춥스', '츄파춥스', '츄파춥스', '츄파춥스', '삼각김밥', '레쓰비캔커피', '코카콜라', '바나나맛우유', '도시락', '삼다수', '삼각김밥']
# 이진 탐색 트리 구성 완료!
# 오늘 판매된 종류(중복X)-->  삼각김밥 레쓰비캔커피 도시락 바나나맛우유 삼다수 츄파춥스 코카콜라
